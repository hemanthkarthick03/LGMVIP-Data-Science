# %% [markdown]
# <center><h2> LetsGrowMore - Data Analyst Intern 📈📊  </h2></center>
# <center><h3> Beginner Level Task 🎯 </h3></center>
# <center><h1> Iris Flowers Classification 🌷</h1></center>
# <center><h3> Hemanth Karthick 😊 <h3></center>

# %% [markdown]
# ## Importing Libraries 📚

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skplt

# %% [markdown]
# ******************

# %% [markdown]
# ## Loading Dataset "Iris"

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <center> <h3> Display the First 5 Rows of the Dataframe</h3> </center>

# %%
#For 'n' number of rows - df.head(n)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# <center> <h3> Display the Last 5 Rows of the Dataframe </h3> </center>

# %%
#For 'n' number of rows - df.tail(n)
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# <center> <h3> Description of the Dataframe </h3> </center>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# <center> <h3> Missing Values of the Dataframe </h3> </center>

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ********

# %% [markdown]
# <center><h2> Data Visualization Models</h2><center>

# %% [markdown]
# + BarPlot
# + Scatterplot
# + Chart
# + Histogram
# + Box Plot
# + Line Chart
# + Heatmap
# + Pairplot
# + Line Graph

# %% [markdown]
# ### Bar Plot - Species vs (Petal / Sepal) Size

# %%
plt.bar(df['species'],df['petal_width'])
plt.title("Species vs Petal Width")
plt.show()

# %%
plt.bar(df['species'],df['petal_length'])
plt.title("Species vs Petal Length")
plt.show()

# %%
plt.bar(df['species'],df['sepal_width'])
plt.title("Species vs Sepal Width")
plt.show()

# %%
plt.bar(df["species"],df["sepal_length"])
plt.title("Species vs Sepal Length")
plt.show()

# %% [markdown]
# ### Pairplot - Species

# %%
sns.pairplot(df,hue="species")

# %% [markdown]
# ### Boxplot - Species vs (Petal / Sepal) Size

# %%
sns.boxplot(data=df,x='species',y='petal_width')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.boxplot(data=df,x='species',y='petal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=df,x='species',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(data=df,x='species',y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ### Heat Map - Maps the Correlations between Columns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info() # Deatails about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ****

# %% [markdown]
# <center><h2>Model Training</h2></center>

# %% [markdown]
# #### Deleting 'Species' Field

# %%
X=df.drop(['species'],axis=1)
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Y=df['species']
Y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 60            5.0          2.0           3.5          1.0
# 116           6.5          3.0           5.5          1.8
# 144           6.7          3.3           5.7          2.5
# 119           6.0          2.2           5.0          1.5
# 108           6.7          2.5           5.8          1.8
# ..            ...          ...           ...          ...
# 9             4.9          3.1           1.5          0.1
# 103           6.3          2.9           5.6          1.8
# 67            5.8          2.7           4.1          1.0
# 117           7.7          3.8           6.7          2.2
# 47            4.6          3.2           1.4          0.2
#
# [105 rows x 4 columns]

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 114           5.8          2.8           5.1          2.4
# 62            6.0          2.2           4.0          1.0
# 33            5.5          4.2           1.4          0.2
# 107           7.3          2.9           6.3          1.8
# 7             5.0          3.4           1.5          0.2
# 100           6.3          3.3           6.0          2.5
# 40            5.0          3.5           1.3          0.3
# 86            6.7          3.1           4.7          1.5
# 76            6.8          2.8           4.8          1.4
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 51            6.4          3.2           4.5          1.5
# 73            6.1          2.8           4.7          1.2
# 54            6.5          2.8           4.6          1.5
# 63            6.1          2.9           4.7          1.4
# ...

# %%
Y_test
# Out:
# 114     virginica
# 62     versicolor
# 33         setosa
# 107     virginica
# 7          setosa
# 100     virginica
# 40         setosa
# 86     versicolor
# 76     versicolor
# 71     versicolor
# 134     virginica
# 51     versicolor
# 73     versicolor
# 54     versicolor
# 63     versicolor
# 37         setosa
# 78     versicolor
# 90     versicolor
# 45         setosa
# 16         setosa
# 121     virginica
# 66     versicolor
# 24         setosa
# 8          setosa
# 126     virginica
# 22         setosa
# 44         setosa
# 97     versicolor
# 93     versicolor
# 26         setosa
# 137     virginica
# 84     versicolor
# 27         setosa
# 127     virginica
# 132     virginica
# 59     versicolor
# 18         setosa
# 83     versicolor
# 61     versicolor
# 92     versicolor
# 112     virginica
# 2          setosa
# 141     virginica
# 43         setosa
# 10         setosa
# Name: species, dtype: object

# %%
Y_train
# Out:
# 85     versicolor
# 30         setosa
# 101     virginica
# 94     versicolor
# 64     versicolor
#           ...
# 9          setosa
# 103     virginica
# 67     versicolor
# 117     virginica
# 47         setosa
# Name: species, Length: 90, dtype: object

# %% [markdown]
# ****
# # Model Prepration

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier #Define Classifier
rfc = RandomForestClassifier(n_estimators=10)

rfc
# Out:
# RandomForestClassifier(n_estimators=10)

# %% [markdown]
# #### Train the Classifier

# %%
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %% [markdown]
# #### Test Phase

# %%
Y_test_pred = rfc.predict(X_test)
Y_train_pred = rfc.predict(X_train)

# %% [markdown]
# #### Accuracy

# %%
from sklearn.metrics import accuracy_score

test_accuracy = accuracy_score(Y_test,Y_test_pred)
train_accuracy = accuracy_score(Y_train,Y_train_pred)

print("Training Accuracy : {}".format(test_accuracy))
print("Test Accuracy : {}".format(train_accuracy))
# Out:
# Training Accuracy : 0.9777777777777777
# Test Accuracy : 0.9904761904761905

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      0.94      0.97        18
#    virginica       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# *************
# <center><h1> Conclusion 🎯 </h1></center>
#
# ****
#
# <center><h3> Iris Flower Classification using Random Forest </h3></center>

# %% [markdown]
#  The Model showcases robust performance with high precision, recall, and F1-score, making it a reliable choice for this flower classification task is
#
# ## Training Accuracy - 99%
#
# ## Test Accuracy - 97%
